# %%
import sys
sys.path.append("C:\\Users\\Guillermo\\Desktop\\Python\\05. Lib gestión pública")

import redapyx
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
gdf=redapyx.get(table_type="frequency", var1="hogar.C3P213",selection="150131", area_break="manzana", output='geodata', pivot=True)
# Out:
# Scraping starts
# REDATAM webpage opened successfully
# Output table loaded successfully
# Table was scraped successfully in: 0:00:11.358489
# Table was cleaned successfully in: 0:00:03.903745

# %%
gdf.plot("join2", legend=True)
# Out:
# <Axes: >
